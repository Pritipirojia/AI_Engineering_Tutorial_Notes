# %% [markdown]
# <a href="https://colab.research.google.com/github/Pritipirojia/AI_Engineering_Tutorial_Notes/blob/main/pandas_series_fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pandas

# %% [markdown]
# Pandas is a powerful library used for data manipulation and analysis. It helps us to work with data in Tabular format, just like how we deal with data and spreadsheet in excel or data.

# %% [markdown]
# Pandas provides functionalities and attributes to clean, organize and analyze large amounts of data

# %% [markdown]
# 1. Easy to use---> Works like Excel inside python
# 2. Fast---> Handles large data faster than manual methods
# 3. Clean data---> helps clean, filter and transform messy data
# 4. Integrates well---> Matplotlib, Seaborn
# 5. Ideal for data science, ML and AI

# %%
pip install pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Pandas series is a column of data in a table like in excel or google sheets with labels called as indexes attached to each value

# %%
pd.Series(data=[40,50,60],index=['Bread', 'Milk', 'Butter'], name='Price of grocery items')
# Out:
# Bread     40
# Milk      50
# Butter    60
# Name: Price of grocery items, dtype: int64

# %% [markdown]
# Whenever you create a series, data type is always going to be decided on the basis of the values itself that are there in the series

# %% [markdown]
# Series is a 1D array that can hold any type of data like integers, float, string (objects), boolean, mixed data type.

# %% [markdown]
# ## Creating a series in multiple ways
# 1. List
# 2. Numpy array
# 3. Dictionary
# 4. custom index
# 5. scalar value

# %%
## series from list
country=['India', 'china', 'USA', 'Pakistan']
pd.Series(country)
# Out:
# 0       India
# 1       china
# 2         USA
# 3    Pakistan
# dtype: object

# %%
batsman_runs=[48,64,73,98,65,90]
pd.Series(batsman_runs, dtype='int32')
# Out:
# 0    48
# 1    64
# 2    73
# 3    98
# 4    65
# 5    90
# dtype: int32

# %%
subject_names=['Maths', 'Physics', 'Chemistry', 'English']
subject_marks=[48,92,67,98]

pd.Series(data=subject_marks, index=subject_names, name='Subject Marks data', dtype='int32')
# Out:
# Maths        48
# Physics      92
# Chemistry    67
# English      98
# Name: Subject Marks data, dtype: int32

# %%
### Creating an series using a numpy array
values=np.arange(10,21)
pd.Series(values)
# Out:
# 0     10
# 1     11
# 2     12
# 3     13
# 4     14
# 5     15
# 6     16
# 7     17
# 8     18
# 9     19
# 10    20
# dtype: int64

# %% [markdown]
# ## Dictionary to Series
#
# Dictionary is another data structure that stores the data in a key value pair and just because it stores the data in a key value pair so we don't have to explicitly mention the index

# %%
data_items={'Maths':78, 'English':92, 'Physics':88, 'Chemistry':64}
pd.Series(data_items)
# Out:
# Maths        78
# English      92
# Physics      88
# Chemistry    64
# dtype: int64

# %%
## custom index to Series
values=[1,2,3,4,5]
pd.Series(data=values, index=['a','b','c','d','e'])
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
## Scalar value inside an Series

pd.Series(4,index=['a','b','c','d','e'])
# Out:
# a    4
# b    4
# c    4
# d    4
# e    4
# dtype: int64

# %% [markdown]
# read_csv()--->this function reads the content from the csv file in pandasso that we can perform the operations on the data or we can perform effective analysis

# %%
Data= pd.read_csv('/content/youtube_2025_dataset_202504061614.csv')

# %%
Data
# Out:
#                      Channel Name       Youtuber Name  Total Videos  \
# 0                 Smith-Ross Labs          Eric Patel            68
# 1                Sandoval PLC Hub  Cynthia Harrington           128
# 2     Jones, Moore and Ho Network       Amanda Walker           282
# 3            Mitchell-Hooper Labs   Jessica Nelson MD           302
# 4              Wilson LLC Studios     Matthew Sherman           129
# ...                           ...                 ...           ...
# 4995        Flores-Daniel Studios       Jasmine Smith           106
# 4996     Spencer and Sons Studios      John Rasmussen           130
# 4997       Obrien-Roberts Studios          Lisa Burke           179
# 4998                 King Ltd Hub          Steve Diaz           182
# 4999            Henry Ltd Studios         Austin Tate            92
#
#                               Best Video  Avg Video Length (min)  \
# 0              VR Challenge: Review 2023                    24.8
# ...

# %%
## 2nd way as the file is in same folder

youtube=pd.read_csv('youtube_2025_dataset_202504061614.csv')

# %%
youtube
# Out:
#                      Channel Name       Youtuber Name  Total Videos  \
# 0                 Smith-Ross Labs          Eric Patel            68
# 1                Sandoval PLC Hub  Cynthia Harrington           128
# 2     Jones, Moore and Ho Network       Amanda Walker           282
# 3            Mitchell-Hooper Labs   Jessica Nelson MD           302
# 4              Wilson LLC Studios     Matthew Sherman           129
# ...                           ...                 ...           ...
# 4995        Flores-Daniel Studios       Jasmine Smith           106
# 4996     Spencer and Sons Studios      John Rasmussen           130
# 4997       Obrien-Roberts Studios          Lisa Burke           179
# 4998                 King Ltd Hub          Steve Diaz           182
# 4999            Henry Ltd Studios         Austin Tate            92
#
#                               Best Video  Avg Video Length (min)  \
# 0              VR Challenge: Review 2023                    24.8
# ...

# %%
subs=youtube['Total Subscribers']

# %%
subs
# Out:
# 0       8264152
# 1       8768222
# 2       6163386
# 3       4712268
# 4       9592017
#          ...
# 4995    2665835
# 4996     136992
# 4997    2314561
# 4998    6954832
# 4999    6785166
# Name: Total Subscribers, Length: 5000, dtype: int64

# %% [markdown]
# ## MAthematical functions in Pandas
#
# ### 1. sum() ---> sum of all values present in the series

# %%
subs.sum()
# Out:
# np.int64(25292407967)

# %% [markdown]
# ### 2. product()---> product of all the values in the series

# %%
subs.product()

## output is zero as the product value of all the subscribers is very large
# Out:
# np.int64(0)

# %%
subs.sort_values()
# Out:
# 3595       1755
# 3204       2910
# 2470       8649
# 4584       9029
# 2615       9436
#          ...
# 3969    9991900
# 380     9992512
# 1177    9995049
# 3593    9999559
# 1931    9999975
# Name: Total Subscribers, Length: 5000, dtype: int64

# %% [markdown]
# ### 3. mean()---> Mean provides us with the average value of the data column

# %%
subs.mean()
# Out:
# np.float64(5058481.5934)

# %% [markdown]
# ### 4. median()---> Median also provides the idea about the average of the data. for coming up with median , we need to sort the values in ascending order and then the middle value after sorting the data is the median.

# %%
subs.median()
# Out:
# 5105967.0

# %% [markdown]
# ### mode()---> mode provides us with the idea that which value is getting repeated maximum number of times

# %%
subs.mode()
# Out:
# 0          1755
# 1          2910
# 2          8649
# 3          9029
# 4          9436
#          ...
# 4995    9991900
# 4996    9992512
# 4997    9995049
# 4998    9999559
# 4999    9999975
# Name: Total Subscribers, Length: 5000, dtype: int64

# %%
avg=youtube['Avg Video Length (min)']

# %%
avg
# Out:
# 0       24.8
# 1       22.9
# 2       24.0
# 3       24.6
# 4       24.6
#         ...
# 4995    22.0
# 4996    26.3
# 4997    25.2
# 4998    24.5
# 4999    25.2
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
avg.mode()
# Out:
# 0    24.1
# Name: Avg Video Length (min), dtype: float64

# %% [markdown]
# ### std()---> if I need to get the idea that how the values inside the series are distributed from the average or mean value then we can come up with the standard deviation

# %%
avg.std()
# Out:
# 0.8745549483431736

# %%
subs.std()
# Out:
# 2890894.947500023

# %% [markdown]
# ### variance---> variance also provides the insight about the distribution of the data from the mean value. And variance is the square of the standard deviation.

# %%
avg.var()
# Out:
# 0.7648463576715311

# %% [markdown]
# ### min()---> minimum value in the series
# ### max()---> maximum value in the series

# %%
avg.min()
# Out:
# 19.1

# %%
avg.max()
# Out:
# 28.9

# %% [markdown]
# ### describe()---> describe function provides the idea about the summary of the important mathematical calculations for the data
#
# It provides below details:
# i. count---> total number of rows
# ii. mean--->mean
# iii. std---> standard deviation
# iv. min--->  minimum value
# v. 25% --->25% of the values are less than this specifiv value
# vi. 50%	--->50% of the values are less than this specifiv value
# vii. 75% --->75% of the values are less than this specifiv value
# viii. max	---> maximum value

# %%
avg.describe()
# Out:
# count    5000.000000
# mean       24.004540
# std         0.874555
# min        19.100000
# 25%        23.500000
# 50%        24.000000
# 75%        24.500000
# max        28.900000
# Name: Avg Video Length (min), dtype: float64

# %% [markdown]
# ## Indexing in Series (To have the access over the certain value or values)
#
# ### 1. Positive indexing (just like list) ---> start from 0 to forward direction
# ### 2. No negative indexing

# %%
avg[2]
# Out:
# np.float64(24.0)

# %% [markdown]
# ### 3. Slicing ---> In series we can get the certain values over a given specific range and we can do it using [initial_val:final_val+1]

# %%
avg[7:18]
# Out:
# 7     25.6
# 8     23.1
# 9     24.2
# 10    22.9
# 11    25.4
# 12    26.9
# 13    23.4
# 14    24.1
# 15    24.9
# 16    24.7
# 17    24.8
# Name: Avg Video Length (min), dtype: float64

# %% [markdown]
# If I want the values skipped as a certain value

# %%
avg[2:12:2]
# Out:
# 2     24.0
# 4     24.6
# 6     23.2
# 8     23.1
# 10    22.9
# Name: Avg Video Length (min), dtype: float64

# %% [markdown]
# ### Reverse values in a series

# %%
avg[::-1]
# Out:
# 4999    25.2
# 4998    24.5
# 4997    25.2
# 4996    26.3
# 4995    22.0
#         ...
# 4       24.6
# 3       24.6
# 2       24.0
# 1       22.9
# 0       24.8
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %% [markdown]
# 4. Fancy Indexing---> if I want the specific values from the series than we go with fancy indexing

# %%
avg[[2,4,9]]
# Out:
# 2    24.0
# 4    24.6
# 9    24.2
# Name: Avg Video Length (min), dtype: float64

# %%
avg[[55,1008,79,56,69]]
# Out:
# 55      24.9
# 1008    23.3
# 79      25.1
# 56      23.0
# 69      24.0
# Name: Avg Video Length (min), dtype: float64

# %% [markdown]
# 5. Indexing with labels---> A series which is consisting of labels as the index or custom index, then for this data we can retrieve the data using that custom index or label

# %%
## DataFrame--> Combination of Multiple Series(Columns)

type(pd.read_csv('youtube_two_column.csv')) ## to know if youtube is a dataframe or not
# Out:
# pandas.core.frame.DataFrame

# %%
## Squeeze---> squeeze parameter makes sure that the data is in series format
## index_col
df = pd.read_csv('youtube_two_column.csv', index_col=0).squeeze("columns")
df
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington    128
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
#                      ...
# Jasmine Smith         106
# John Rasmussen        130
# Lisa Burke            179
# Steve Diaz            182
# Austin Tate            92
# Name: Total Videos, Length: 5000, dtype: int64

# %%
type(df)
# Out:
# pandas.core.series.Series

# %%
##Indexing with labels

df['Eric Patel']
# Out:
# np.int64(68)

# %% [markdown]
# ### Editing Series (Bring the changes into the values stored inside the series)
#
# 1. Using Indexing --->df[0]=65---> changing the original value at index 0 to 65

# %%
df['Eric Patel']=60

# %%
df['Eric Patel']
# Out:
# np.int64(60)

# %% [markdown]
# ### if indexing doesn't exist and you try to change the value, it will add the value with that index to the dataframe

# %%
df['Amit kumar Singh']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.13/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# index.pyx in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: 'Amit kumar Singh'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1168/1009213671.py in <cell line: 0>()
# ----> 1 df['Amit kumar Singh']
#
# ...

# %%
df['Amit kumar Singh']=78

# %%
df
# Out:
# Youtuber Name
# Eric Patel             60
# Cynthia Harrington    128
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
#                      ...
# John Rasmussen        130
# Lisa Burke            179
# Steve Diaz            182
# Austin Tate            92
# Amit kumar Singh       78
# Name: Total Videos, Length: 5001, dtype: int64

# %% [markdown]
# ### Slicing in Series ---> df[2:7]=100--->100 will be associated for index 2 to 6

# %%
avg[1:5]=28
# Out:
# /tmp/ipykernel_1168/2504678467.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg[1:5]=28

# %%
avg
# Out:
# 0       24.8
# 1       28.0
# 2       28.0
# 3       28.0
# 4       28.0
#         ...
# 4995    22.0
# 4996    26.3
# 4997    25.2
# 4998    24.5
# 4999    25.2
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %% [markdown]
# ## Fancy indexing ---> df[2,4,8]=[45,84,79]

# %%
avg[[4,4998,4996,0]]=[25,21,20,24]
# Out:
# /tmp/ipykernel_1168/2428048921.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg[[4,4998,4996,0]]=[25,21,20,24]

# %%
avg
# Out:
# 0       24.0
# 1       28.0
# 2       28.0
# 3       28.0
# 4       25.0
#         ...
# 4995    22.0
# 4996    20.0
# 4997    25.2
# 4998    21.0
# 4999    25.2
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %% [markdown]
# ## Index Labelling

# %%
df[['Eric Patel', 'Jessica Nelson MD','Amit kumar Singh']]=[45,210,200]

## we  will discuss later as it requires loc function
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.13/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '['Eric Patel', 'Jessica Nelson MD', 'Amit kumar Singh']' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# /usr/local/lib/python3.13/dist-packages/pandas/core/series.py in __setitem__(self, key, value)
#    1297         try:
# -> 1298             self._set_with_engine(key, value, warn=warn)
#    1299         except KeyError:
#
# ...

# %% [markdown]
# ## DataFrame--> Combination of Multiple Series(Columns)

# %% [markdown]
# ## Squeeze---> squeeze parameter makes sure that the data is in series format

# %% [markdown]
# Squeeze when csv file has one column

# %%
df = pd.read_csv('youtube_one_column.csv').squeeze("columns")
df
# Out:
# 0                   Smith-Ross Labs
# 1                  Sandoval PLC Hub
# 2       Jones, Moore and Ho Network
# 3              Mitchell-Hooper Labs
# 4                Wilson LLC Studios
#                    ...
# 4995          Flores-Daniel Studios
# 4996       Spencer and Sons Studios
# 4997         Obrien-Roberts Studios
# 4998                   King Ltd Hub
# 4999              Henry Ltd Studios
# Name: Channel Name, Length: 5000, dtype: object

# %%
type(df)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Squeeze when csv file has two column

# %%
pd.read_csv('youtube_two_column.csv')
# Out:
#            Youtuber Name  Total Videos
# 0             Eric Patel            68
# 1     Cynthia Harrington           128
# 2          Amanda Walker           282
# 3      Jessica Nelson MD           302
# 4        Matthew Sherman           129
# ...                  ...           ...
# 4995       Jasmine Smith           106
# 4996      John Rasmussen           130
# 4997          Lisa Burke           179
# 4998          Steve Diaz           182
# 4999         Austin Tate            92
#
# [5000 rows x 2 columns]

# %% [markdown]
# ## index_col (parameter to use when you want to refer to one column as index)

# %%
dataframe=pd.read_csv('youtube_two_column.csv', index_col='Youtuber Name').squeeze('columns')

# %%
dataframe
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington    128
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
#                      ...
# Jasmine Smith         106
# John Rasmussen        130
# Lisa Burke            179
# Steve Diaz            182
# Austin Tate            92
# Name: Total Videos, Length: 5000, dtype: int64

# %% [markdown]
# ## Attribute in Series
#
# 1. .values---> representing only the values of the given series

# %%
df.values
# Out:
# array(['Smith-Ross Labs', 'Sandoval PLC Hub',
#        'Jones, Moore and Ho Network', ..., 'Obrien-Roberts Studios',
#        'King Ltd Hub', 'Henry Ltd Studios'], dtype=object)

# %%
dataframe.values
# Out:
# array([ 68, 128, 282, ..., 179, 182,  92])

# %% [markdown]
# 2. .index---> returns only the index values from the given column

# %%
dataframe
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington    128
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
#                      ...
# Jasmine Smith         106
# John Rasmussen        130
# Lisa Burke            179
# Steve Diaz            182
# Austin Tate            92
# Name: Total Videos, Length: 5000, dtype: int64

# %%
dataframe.values
# Out:
# array([ 68, 128, 282, ..., 179, 182,  92])

# %%
dataframe.index
# Out:
# Index(['Eric Patel', 'Cynthia Harrington', 'Amanda Walker',
#        'Jessica Nelson MD', 'Matthew Sherman', 'Anna Berry', 'Richard Arnold',
#        'Stephanie Potter', 'Teresa Aguirre', 'Anne Adkins',
#        ...
#        'Erin Bradley', 'Brooke Perez', 'Nicholas Jordan', 'Howard Phelps',
#        'Sharon Graham', 'Jasmine Smith', 'John Rasmussen', 'Lisa Burke',
#        'Steve Diaz', 'Austin Tate'],
#       dtype='object', name='Youtuber Name', length=5000)

# %% [markdown]
# 3. dtype ---> Dtype provides the idea about the data type of the values that you are storing

# %%
dataframe.dtype
# Out:
# dtype('int64')

# %%
dataframe.astype('int32')
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington    128
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
#                      ...
# Jasmine Smith         106
# John Rasmussen        130
# Lisa Burke            179
# Steve Diaz            182
# Austin Tate            92
# Name: Total Videos, Length: 5000, dtype: int32

# %% [markdown]
# 4. size ---> this attribute provides the idea about the total number of rows inside the dataset

# %%
dataframe.size
# Out:
# 5000

# %% [markdown]
# 5. shape---> no. of rows and columns

# %%
dataframe.shape ## it is not giving column as there is only one column in dataframe series
# Out:
# (5000,)

# %% [markdown]
# 6. ndim ---> dimension of the given dataset

# %%
dataframe.ndim
# Out:
# 1

# %% [markdown]
# 7. name ---> provides name of the series

# %%
dataframe.name
# Out:
# 'Total Videos'

# %% [markdown]
# 8. is_unique ---> this provides with the idea about whether if unique values are there inside the column

# %%
dataframe
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington    128
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
#                      ...
# Jasmine Smith         106
# John Rasmussen        130
# Lisa Burke            179
# Steve Diaz            182
# Austin Tate            92
# Name: Total Videos, Length: 5000, dtype: int64

# %%
dataframe.is_unique
# Out:
# False

# %%
pd.Series([1,2,3,4,5]).is_unique
# Out:
# True

# %% [markdown]
# ## Series Methods
#
# 1. head() ---> Provides the top preview of Data as the top 5 rows of the dataframe or series. It is quite helpful with providing the preview of the dataset (default is top 5 rows). It if you want to preview top 10 rows then pass 10 as an argument.

# %%
dataframe
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington    128
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
#                      ...
# Jasmine Smith         106
# John Rasmussen        130
# Lisa Burke            179
# Steve Diaz            182
# Austin Tate            92
# Name: Total Videos, Length: 5000, dtype: int64

# %%
dataframe.head()
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington    128
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
# Name: Total Videos, dtype: int64

# %%
dataframe.head(7)
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington    128
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
# Anna Berry             98
# Richard Arnold        494
# Name: Total Videos, dtype: int64

# %% [markdown]
# 2. tail() ---> Provides the bottom preview of Data as the bottom 5 rows of the dataframe or series. It is quite helpful with providing the preview of the dataset (default is bottom 5 rows). It if you want to preview bottom 10 rows then pass 10 as an argument.

# %%
dataframe.tail()
# Out:
# Youtuber Name
# Jasmine Smith     106
# John Rasmussen    130
# Lisa Burke        179
# Steve Diaz        182
# Austin Tate        92
# Name: Total Videos, dtype: int64

# %%
dataframe.tail(7)
# Out:
# Youtuber Name
# Howard Phelps     126
# Sharon Graham     231
# Jasmine Smith     106
# John Rasmussen    130
# Lisa Burke        179
# Steve Diaz        182
# Austin Tate        92
# Name: Total Videos, dtype: int64

# %% [markdown]
# 3. sample() ---> provides any custom row from the dataset for us to preview

# %%
dataframe.sample() ## output is one random row
# Out:
# Youtuber Name
# Chad Rodriguez    215
# Name: Total Videos, dtype: int64

# %%
dataframe.sample(5) ## output is 5 random rows
# Out:
# Youtuber Name
# Darren Gray         129
# Victoria Garrett    367
# Jillian Gray        192
# Brittany Wong       406
# Zachary Phillips    478
# Name: Total Videos, dtype: int64

# %% [markdown]
# 4. value_counts() ---> provides the idea about the count of the values (catagorical values), if i am having a column where the categorical value count I want to calculate then I can go with value_counts()

# %%
youtube=pd.read_csv('youtube_2025_dataset_202504061614.csv')
youtube
# Out:
#                      Channel Name       Youtuber Name  Total Videos  \
# 0                 Smith-Ross Labs          Eric Patel            68
# 1                Sandoval PLC Hub  Cynthia Harrington           128
# 2     Jones, Moore and Ho Network       Amanda Walker           282
# 3            Mitchell-Hooper Labs   Jessica Nelson MD           302
# 4              Wilson LLC Studios     Matthew Sherman           129
# ...                           ...                 ...           ...
# 4995        Flores-Daniel Studios       Jasmine Smith           106
# 4996     Spencer and Sons Studios      John Rasmussen           130
# 4997       Obrien-Roberts Studios          Lisa Burke           179
# 4998                 King Ltd Hub          Steve Diaz           182
# 4999            Henry Ltd Studios         Austin Tate            92
#
#                               Best Video  Avg Video Length (min)  \
# 0              VR Challenge: Review 2023                    24.8
# ...

# %%
avg=youtube['Avg Video Length (min)']
avg
# Out:
# 0       24.8
# 1       22.9
# 2       24.0
# 3       24.6
# 4       24.6
#         ...
# 4995    22.0
# 4996    26.3
# 4997    25.2
# 4998    24.5
# 4999    25.2
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
type(avg)
# Out:
# pandas.core.series.Series

# %%
avg.value_counts()
# Out:
# Avg Video Length (min)
# 24.1    276
# 23.8    264
# 23.9    256
# 24.2    253
# 24.0    251
#        ...
# 21.2      1
# 28.0      1
# 27.3      1
# 21.0      1
# 20.7      1
# Name: count, Length: 78, dtype: int64

# %% [markdown]
# 5. sort_values() ---> sorts the values in ascending order

# %%
avg.sort_values()
# Out:
# 500     19.1
# 451     19.3
# 1713    19.9
# 171     20.6
# 3704    20.7
#         ...
# 2748    28.0
# 925     28.1
# 364     28.3
# 1467    28.4
# 361     28.9
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %% [markdown]
# ## parameter ---> ascending =false (sorting ---> descending)

# %%
avg.sort_values(ascending=False)
# Out:
# 361     28.9
# 1467    28.4
# 364     28.3
# 925     28.1
# 2748    28.0
#         ...
# 3704    20.7
# 171     20.6
# 1713    19.9
# 451     19.3
# 500     19.1
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %% [markdown]
# ## Method chaining ---> we will be using multiple meethods to get the required value in a way the first method's output will be second method input  then second method output will be third method input

# %%
avg.sort_values(ascending=False).head()
# Out:
# 361     28.9
# 1467    28.4
# 364     28.3
# 925     28.1
# 2748    28.0
# Name: Avg Video Length (min), dtype: float64

# %%
avg.sort_values(ascending=False).head(7).values[0]
# Out:
# np.float64(28.9)

# %%
avg
# Out:
# 0       24.8
# 1       22.9
# 2       24.0
# 3       24.6
# 4       24.6
#         ...
# 4995    22.0
# 4996    26.3
# 4997    25.2
# 4998    24.5
# 4999    25.2
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
average=avg.copy() ##to use inplace parameter we need to copy the data first
average
# Out:
# 0       24.8
# 1       22.9
# 2       24.0
# 3       24.6
# 4       24.6
#         ...
# 4995    22.0
# 4996    26.3
# 4997    25.2
# 4998    24.5
# 4999    25.2
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
### in order to make a change in our data permanent ---> inplace
average.sort_values(inplace=True)
average
# Out:
# 500     19.1
# 451     19.3
# 1713    19.9
# 171     20.6
# 3704    20.7
#         ...
# 2748    28.0
# 925     28.1
# 364     28.3
# 1467    28.4
# 361     28.9
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
average
# Out:
# 500     19.1
# 451     19.3
# 1713    19.9
# 171     20.6
# 3704    20.7
#         ...
# 2748    28.0
# 925     28.1
# 364     28.3
# 1467    28.4
# 361     28.9
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %% [markdown]
# 6. sort_index()---> this method sorts the index of the dataset

# %%
dataframe
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington    128
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
#                      ...
# Jasmine Smith         106
# John Rasmussen        130
# Lisa Burke            179
# Steve Diaz            182
# Austin Tate            92
# Name: Total Videos, Length: 5000, dtype: int64

# %%
dataframe.sort_index()
# Out:
# Youtuber Name
# Aaron Archer        136
# Aaron Bishop        151
# Aaron Brown          51
# Aaron Burns         314
# Aaron Carrillo      210
#                    ...
# Zachary Phillips    478
# Zachary Russell      81
# Zachary Shelton     446
# Zoe Peterson         78
# Zoe Smith            83
# Name: Total Videos, Length: 5000, dtype: int64
